# %%
import pandas as pd
import requests
pd.set_option('display.max_columns', None)
pd.set_option("display.max_colwidth", None)
'26SYMV018611768'
ref_number = "26SYMV018611768"
url = "https://cerpp.eprocurement.gov.gr/khmdhs-opendata/contract?page=0"

r = requests.post(
    url,
    json={"referenceNumber": ref_number},
    headers={"Accept": "application/json", "Content-Type": "application/json"},
    timeout=30,
)
r.raise_for_status()

data = r.json()
df_ref = pd.json_normalize(data.get("content", []))
df_ref
# Out:
#                                     title  referenceNumber prevReferenceNo  \
# 0  Ευπρεπισμός Οδικού Δικτύου ΠΕ Κέρκυρας  26SYMV018611768            None
#
#   noticeReferenceNumber           submissionDate lastUpdateDate  \
# 0                  None  2026-03-10T10:56:39.264           None
#
#   contractSignedDate   startDate  noEndDate     endDate  cancelled  \
# 0         2026-03-09  2026-03-09      False  2026-11-08      False
#
#   cancellationDate cancellationType cancellationReason cancellationADA  \
# 0             None             None               None            None
#
#   decisionRelatedAda contractNumber authorEmail organizationVatNumber  \
# 0               None            642        None             802544756
#
#    greekOrganizationVatNumber commitmentNo diavgeiaADA              aaht  \
# 0                        True         None        None  1007.F01364.0001
#
#   budget  contractBudget bidsSubmitted  maxBidsSubmitted  numberOfSections  \
# 0   None       147999.16          None                 1                 1
#
#                                           nutsCodes approvedRequestsList  \
# 0  [{'nutsCode': {'key': 'EL', 'value': 'ΕΛΛΑΔΑ'}}]                   []
#
#   awardProcedure nutsCity nutsPostalCode  \
# 0           None  Κέρκυρα          49100
#
#                                                       centralizedMarkets  \
# 0  [{'centralizedMarket': {'key': '8', 'value': 'Δεν χρησιμοποιείται'}}]
#
#    contractDuration  totalCostWithVAT  totalCostWithoutVAT  \
# 0                 8         183518.96            147999.16
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    objectDetailsList  \
# 0  [{'quantity': 1, 'type': {'key': 'E48', 'value': 'Υπηρεσία'}, 'costWithoutVAT': 147999.16, 'vat': '24', 'currency': {'key': 'EUR', 'value': 'Ευρώ'}, 'shortDescription': 'Το αντικείμενο των εργασιών αφορά στον ευπρεπισμό του οδικού δικτύου Π.Ε. Κέρκυρας (Εθνικού και Περιφερειακού).  Προβλέπεται  ο καθαρισμός από την βλάστηση (αποψίλωση, κλάδεμα) που βρίσκεται στις τάφρους, στα πρανή, στα ερείσματα και στις νησίδες των οδών, η συλλογή των προϊόντων καθαρισμού και η απομάκρυνση τους.  ', 'cpvs': [{'key': '77312000-0', 'value': 'Υπηρεσίες εκκαθάρισης από αγριόχορτα'}, {'key': '77211400-6', 'value': 'Υπηρεσίες κοπής δένδρων'}], 'greenContracts': {'key': '1', 'value': 'Δεν εμπίπτει στο ΕΣΔ'}, 'goodServices': None, 'cityOfConstruction': None, 'countryOfDelivery': {'key': 'GR', 'value': 'Ελλάδα'}, 'addressForDelivery': None, 'postalCode': None, 'city': 'ΚΕΡΚΥΡΑ', 'streetNumber': None, 'budgetCode': None, 'requestRefNo': '26AWRD018408971'}]
#
#   additionalContractTypes  mixedContract requestRefNo nextRefNo nextExtended  \
# 0                    None          False         None      None         None
#
#   nextModified     auctionRefNo paymentRefNo assignedContract.key  \
# 0         None  26AWRD018408971           []                    2
#
#   assignedContract.value socialContract.key socialContract.value  \
# 0                    Όχι                  2                  Όχι
#
#   centralGovernmentAuthority.key centralGovernmentAuthority.value  \
# 0                              2                              Όχι
#
#   organization.key  \
# 0        100092215
#
#                                                                  organization.value  \
# 0  ΙΟΝΙΑ ΑΝΑΠΤΥΞΗ ΑΝΑΠΤΥΞΙΑΚΟΣ ΟΡΓΑΝΙΣΜΟΣ ΟΤΑ ΠΕΡΙΦΕΡΕΙΑΣ ΙΟΝΙΩΝ ΝΗΣΩΝ (ΑΟΠΙΝ) Α.Ε.
#
#   procedureType.key procedureType.value nutsCode.key nutsCode.value  \
# 0                 1  Ανοιχτή διαδικασία        EL622        Κέρκυρα
#
#   nutsCountry.key nutsCountry.value legalContext.key  \
# 0              GR            Ελλάδα                5
#
#                         legalContext.value contractType.key  \
# 0  ν.4412/2016 - Βιβλίο Ι – κάτω των ορίων                9
#
#   contractType.value assignCriteria.key assignCriteria.value  \
# 0          Υπηρεσίες                  9          Βάσει τιμής
#
#   classificationOfPublicLawOrganization.key  \
# 0                                         4
#
#   classificationOfPublicLawOrganization.value typeOfContractingAuthority.key  \
# 0                    Εκτός Γενικής Κυβέρνησης                             10
#
#   typeOfContractingAuthority.value contractingAuthorityActivity.key  \
# 0                             ΝΠΙΔ                                1
#
#   contractingAuthorityActivity.value contractDurationUnitOfMeasure.key  \
# 0         Γενικές δημόσιες υπηρεσίες                                 3
#
#   contractDurationUnitOfMeasure.value contractRelatedADA.number1  \
# 0                               Μήνες                       None
#
#   contractRelatedADA.number2 contractRelatedADA.number3  \
# 0                       None             9Ρ9Λ46ΝΘ83-46Ι
#
#   fundingDetails.publicFundingRef fundingDetails.publicFundingRefNum  \
# 0                            None                               None
#
#   fundingDetails.publicFundingRefOps fundingDetails.cofundProgramRef  \
# 0                               None                            None
#
#   fundingDetails.selfFundProgramRef fundingDetails.espaFundProgramRef  \
# 0                                 .                              None
#
#   fundingDetails.regularBudgetFundedProgramRef  \
# 0                                         None
#
#   contractingDataDetails.unitsOperator.key  \
# 0                                100092283
#
#   contractingDataDetails.unitsOperator.value  \
# 0                       ΔΙΟΙΚΗΤΙΚΟ ΣΥΜΒΟΥΛΙΟ
#
#   contractingDataDetails.signers.key     contractingDataDetails.signers.value  \
# 0                          100095991  ΣΠΥΡΙΔΩΝ ΚΡΟΚΙΔΗΣ - Διευθύνων Σύμβουλος
#
#                                                                                                                                      contractingDataDetails.contractingMembersDataList
# 0  [{'country': {'key': 'GR', 'value': 'Ελλάδα'}, 'vatNumber': '999558327', 'greekVatNumber': True, 'name': 'ΚΕΡΚΥΡΑΪΚΗ ΚΑΤΑΣΚΕΥΑΣΤΙΚΗ ΜΟΝΟΠΡΟΣΩΠΗ ΙΔΙΩΤΙΚΗ ΚΕΦΑΛΑΙΟΥΧΙΚΗ ΕΤΑΙΡΕΙΑ '}]
