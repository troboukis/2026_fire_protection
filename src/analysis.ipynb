# %%
import pandas as pd
from fetch_diavgeia import classify_org, enrich_dataframe
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pandas as pd
# ----> 2 from src.fetch_diavgeia import classify_org, enrich_dataframe
#
# ModuleNotFoundError: No module named 'src'

# %%
df = pd.read_csv("../data/2026_diavgeia.csv")

# %%
df.head(3)
# Out:
#               ada     protocolNumber            issueDate  \
# 0     ΡΗΠΒΩ6Ι-ΒΛΒ       2312/24/2026  18/02/2026 02:00:00
# 1  Ψ7ΦΑ4653Π8-Τ98              59413  18/02/2026 02:00:00
# 2     9ΚΠΣΩ1Ε-ΕΑ0  3497 - 18-02-2026  18/02/2026 02:00:00
#
#    submissionTimestamp     publishTimestamp     status  nonRevokable  \
# 0  18/02/2026 12:41:54  18/02/2026 12:41:54  PUBLISHED           NaN
# 1  18/02/2026 12:26:32  18/02/2026 12:26:32  PUBLISHED           NaN
# 2  18/02/2026 11:38:36  18/02/2026 11:38:36  PUBLISHED           NaN
#
#                                   documentUrl  \
# 0     https://diavgeia.gov.gr/doc/ΡΗΠΒΩ6Ι-ΒΛΒ
# 1  https://diavgeia.gov.gr/doc/Ψ7ΦΑ4653Π8-Τ98
# 2     https://diavgeia.gov.gr/doc/9ΚΠΣΩ1Ε-ΕΑ0
#
#                                              subject documentType  \
# 0  Διαμόρφωση προϋπολογισμού του Δήμου Αγιάς έτου...        ΠΡΑΞΗ
# 1  Έγκριση της 1ης Αναλυτικής Επιμέτρησης των εργ...        ΠΡΑΞΗ
# ...

# %%
enrich_dataframe(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 enrich_dataframe(df)
#
# File ~/Code/fire_protection_2026/src/fetch_diavgeia.py:206, in enrich_dataframe(df)
#     203 """Add org, org_type, org_name_clean columns to a raw Diavgeia DataFrame."""
#     205 df = df.copy()
# --> 206 df["org"] = df["organization"].apply(lambda x: x["label"])
#     208 classifications = df["org"].apply(classify_org)
#     209 df["org_type"] = classifications.apply(lambda t: t[0])
#
# File ~/Code/fire_protection_2026/.fireprotection/lib/python3.11/site-packages/pandas/core/series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
# ...
